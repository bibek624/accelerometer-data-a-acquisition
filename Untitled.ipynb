# %%
import serial

import threading

import pandas as pd

import time
from time import sleep
from pySerialTransfer import pySerialTransfer as txfer

import matplotlib.pyplot as plt
import numpy as np

import csv

from IPython.display import display, clear_output
import time
import threading
import ipywidgets as widgets

plt.rcParams['animation.html'] = 'jshtml'
# %matplotlib notebook



class accelerometer():
    x1 = np.array([])
    x2 = np.array([])
    disp = np.array([])

    t = np.array([])

    def plot_data(self):
        # t = np.linspace(0, len(self.x), len(self.x))

        index = 5*80
        if (len(self.t)> index):
            tp = self.t[-index:-1]
            x1p = self.x1[-index:-1]
            x2p = self.x2[-index:-1]
            dispp = self.disp[-index:-1]
        else:
            tp = self.t
            x1p = self.x1
            x2p = self.x2
            dispp = self.disp


        return tp, x1p, x2p, dispp

# %%
a1 = accelerometer()

string = ""

init = True

string = ""

ser = None
if (ser):
    ser.close()

# Create a Serial object
ser = serial.Serial('COM5', 115200)  # Replace 'COM5' with the appropriate port name and '9600' with the correct baud rate


fig, ax = plt.subplots(2, 1, figsize=(11, 9))



ax1 = ax[0]
ax2 = ax[1]

# ax3 = ax[0][1]
# ax4 = ax[1][1]

line1, = ax1.plot([], [])
line2, = ax2.plot([], [])
line3, = ax2.plot([], [])
# fig.canvas.draw()
# line3, = ax1.plot([], [])
#
# line4, = ax2.plot([], [])
# line5, = ax2.plot([], [])
# line6, = ax2.plot([], [])
#
# line7, = ax3.plot([], [])
# line8, = ax3.plot([], [])
# line9, = ax3.plot([], [])
#
# line10, = ax4.plot([], [])
# line11, = ax4.plot([], [])
# line12, = ax4.plot([], [])

#     fig.show()

# display(fig)

# Clear the output after displaying the plot
# clear_output(wait=True)

# Read data from the serial port



ser.read(ser.in_waiting)

ser.setDTR(False)
time.sleep(0.2)
ser.setDTR(True)

time.sleep(0.5)

plt.show(block = False)

# Create a thread object
# thread = threading.Thread(target=read_serial_data)


# Start the thread
# thread.start()


seek = 0;


filee = 'wall_test/mud_3.csv'

read_data = True

stop = False

# Define functions for button clicks
def start_function(_):
    global read_data 
    read_data = True
    print('started')

def stop_function(_):
    global read_data
    read_data = False
    print('stopped')
    
# Create start and stop buttons
start_button = widgets.Button(description="Start")
stop_button = widgets.Button(description="Stop")

# Assign the button click functions
start_button.on_click(start_function)
stop_button.on_click(stop_function)

# Display buttons
display(widgets.HBox([start_button, stop_button]))



# def start_acquisition():
    
#     global ax1, ax2, line1, line2, line3, string, ser, data, fig, init


with open(filee, "w+", newline='') as file:
    writer = csv.writer(file, delimiter=",")

    while True:
        if(not read_data):
                break

        if (ser.in_waiting):

            start_time = time.perf_counter()
            try:
                data = ser.read(ser.in_waiting).decode().strip()
                string = string + data
            except Exception as e:
                print(f'error: {e})')

            if (init):
                if (string[0] != '{'):
                    start_index = data.find('{')
                    if (start_index != -1):
                        string = data[start_index + 1:]
                        print(string)
                        init = False
                else:
                    string = data
                    init = False

            else:
                if ("}{" in string):
                    parts = string.split("}{")
#                     print(parts)
                    for part in parts:
#                         print(part)
                        part = part.split(',')

                        if (len(part) == 5 and part[-1] != "" and part[-1] != "-"):
                            part = [p.replace("}", "") for p in part]
                            part = [p.replace("{", "") for p in part]

                            #                         print(part)
                            try:
                                data_list = [float(p) for p in part]


                                # if (data_list[0] == 1.0):

                                a1.t = np.append(a1.t, data_list[0])
                                a1.x1 = np.append(a1.x1, data_list[1])
                                a1.x2 = np.append(a1.x2, data_list[2])
                                a1.disp = np.append(a1.disp, data_list[3])




                            

                                writer.writerow([data_list[0]*12.5/1000, data_list[1] ,data_list[2], data_list[3]])


                            except Exception as e:
                                print(f'Float Parse error: {part}')

                    if (string[-1] == "}"):
                        string = ""
                    else:
                        start_index = string.rfind("{")
                        string = string[start_index + 1:]

            end_time = time.perf_counter()


            tp, x1p, x2p, dispp = a1.plot_data()

            line1.set_data(tp, dispp)
            line2.set_data(tp, x1p)
            line3.set_data(tp, x2p)



            ax1.relim()
            ax1.autoscale_view()

            ax2.relim()
            ax2.autoscale_view()

            fig.canvas.draw()
            plt.pause(0.01)

                
# function_thread = threading.Thread(target=start_acquisition)

# function_thread.start()

# start_acquisition()
# Close the serial port
ser.close()
# Out:
# <img src="data:image/png;base64,..." width="1100">
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [4], line 120
#     114     writer = csv.writer(file, delimiter=",")
#     116     while True:
#     117 #             if(not read_data):
#     118 #                 continue
# --> 120         if (ser.in_waiting):
#     122             start_time = time.perf_counter()
#     123             try:
#
# AttributeError: 'NoneType' object has no attribute 'in_waiting'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# df = pd.read_csv('acceleration2.csv',header = None)
# # df = df.iloc[50*10:70*10,:]
# df[3] = df[3]-2
# df[1] = df[1] - 50

# df.plot(x = 3, y = 1)



drift = (df[3]/400)*100*-1
df[1] = filtered_signal

force = filtered_signal/100 * 10
plt.figure()
plt.plot(drift, force)

ax = plt.gca()
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')

# # Eliminate the top and right spines
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')


plt.xlabel('Lateral Drift (%)')
plt.ylabel('Force (N)', rotation = 0)
plt.title('Hysterisis Ccurve', pad = 20)

# # plt.title.set_position(0,0)



# # Set x-axis label position to the edge
ax.xaxis.set_label_coords(1, 0.4)

# # Set y-axis label position to the edge
ax.yaxis.set_label_coords(0.5, 1.01)



# plt.savefig('hysteresis-final.png', dpi = 300)

df[0] = df[0]-47.775
# df[1]= filtered_signal
df[1]= force
df[3]= drift

# df[1] = filtered_signal

# df.to_csv('sim_result.csv', index = None)
# df.to_csv('hyst.csv', index = None, header=None)
# df[3].to_csv('top_displacement.csv',index = None)
# df[3].to_csv('top_acceleration.csv',index = None)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import pandas as pd

import numpy as np
from scipy.signal import butter, lfilter, detrend
import matplotlib.pyplot as plt



start = 2500 #sec
end = 3000

df = pd.read_csv('wall_test/mud_2.csv' , header = None)
df = df.iloc[start:end,: ]
df.plot()


# exit()
# print(df)
t = df[0]
fs = 80



# Define the low-pass filter
cutoff_frequency = 2 # Cutoff frequency in Hz
nyquist_frequency = 0.5* fs
b, a = butter(3, cutoff_frequency / nyquist_frequency, btype='low')


# acc = np.append(acc,[0,0])
noisy_signal = df[2]


# Apply the filter
filtered_signal = lfilter(b, a, noisy_signal)
filtered_signal = detrend(filtered_signal)





df[3] = detrend(df[3])
df[3] = lfilter(b, a, df[3])


disp = df[3]




fig, ax = plt.subplots(2,1)



ax[0].plot(t,noisy_signal, label = 'top acceleration (noisy)')
ax[0].plot(t,filtered_signal, label = 'top acceleration (filtered) ')

# df.iloc[0,3] = 0

ax[1].plot(t,(df[3]),  color = 'green', label = 'top displacement')



fig.legend()

print(df)

# plt.savefig('time history, day6-2.png', dpi = 300)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
#             0           1           2         3
# 2500  31.2500  314.941406  431.396484  0.000496
# 2501  31.2625  242.797852  331.604004  0.003418
# 2502  31.2750  282.348633  198.120117  0.011827
# 2503  31.2875  488.159180  119.018555  0.028230
# 2504  31.3000  582.092285  128.173828  0.053435
# ...       ...         ...         ...       ...
# 2995  37.4250  299.926758  205.810547  0.656555
# 2996  37.4375  334.899902  151.794434  0.737493
# 2997  37.4500  324.462891  178.527832  0.811012
# 2998  37.4625  352.111816  232.910156  0.875158
# 2999  37.4750  422.058105  347.900391  0.928602
#
# [500 rows x 4 columns]

# %%
from scipy.signal import butter, lfilter, detrend

cutoff_frequency = 2 # Cutoff frequency in Hz
nyquist_frequency = 0.5* fs
b, a = butter(3, cutoff_frequency / nyquist_frequency, btype='low')


# Apply the filter
filtered_signal = lfilter(b, a, noisy_signal)
filtered_signal = detrend(filtered_signal)





df[3] = detrend(df[3])
df[3] = lfilter(b, a, df[3])


disp = df[3]




fig, ax = plt.subplots(2,1)



ax[0].plot(t,noisy_signal, label = 'top acceleration (noisy)')
ax[0].plot(t,filtered_signal, label = 'top acceleration (filtered) ')

# df.iloc[0,3] = 0

ax[1].plot(t,(df[3]),  color = 'green', label = 'top displacement')



fig.legend()

print(df)

# plt.savefig('time history, day6-2.png', dpi = 300)

# %%
from scipy.signal import savgol_filter
from scipy.signal import butter, lfilter, detrend

start = 500 #sec
end = 8000

df = pd.read_csv('wall_test/mud_1.csv' , header = None)
df = df.iloc[start:end,: ]

acc_u = df[1]

df.plot(x = 0)


acc_f = lfilter(b,a,acc_u)

acc_f = detrend(acc_f)

# # df.plot()

# disp = df[3]/10
# cutoff_frequency = 2# Cutoff frequency in Hz
# nyquist_frequency = 0.5* fs
# b, a = butter(4, cutoff_frequency / nyquist_frequency, btype='low')

# # disp = detrend(disp)
# # disp = savgol_filter(disp,51,3)

# # disp = np.sin(2*3.14*1*np.arange(0,2,0.01))
# disp_f = lfilter(b, a, disp)

# vel = np.diff(disp_f)/0.0125
# # vel = vel + np.roll(vel,-1)
# acc = np.diff(vel)/0.0125
# # acc = acc + np.roll(acc,-1)
# # acc = savgol_filter(acc,33,3)


# # plt.plot(np.array(disp))

# # print(disp)
# # print(disp_f)
# plt.plot(acc)
# plt.plot(np.array(df[1]))
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [7], line 15
#      10 acc_u = df[1]
#      12 df.plot(x = 0)
# ---> 15 acc_f = lfilter(b,a,acc_u)
#      17 acc_f = detrend(acc_f)
#
# NameError: name 'b' is not defined

# %%
from scipy.signal import correlate

df_2 = pd.read_csv('day 7-test2.csv' , header = None)
df_3 = pd.read_csv('day 7-test_final.csv' , header = None)

length = 7000
start = 0

start_2 = 385 + start
end_2 = start_2+length

start_3 = 1825 +start
end_3 = start_3+length

df_2 = df_2.iloc[start_2:end_2,:]
df_3 = df_3.iloc[start_3:end_3,:]



# df_2.plot(y = 2)
# df_3.plot(y = 2)

acc_2 = df_2[2].to_numpy()
acc_3 = df_3[2].to_numpy()

acc_2 = lfilter(b,a,acc_2)
acc_3 = lfilter(b,a,acc_3)

top_acc = df_2[1].to_numpy()

plt.figure()
# plt.plot(acc_2)
plt.plot(df_3[0],acc_3)

cor = correlate(df_2[2].to_numpy(), df_3[2].to_numpy(), mode = 'full')




plt.figure()
plt.plot(top_acc)
# Out:
# <img src="data:image/png;base64,..." width="705.509459351934">
# <img src="data:image/png;base64,..." width="705.509459351934">

# %%
import numpy as np
from scipy.signal import butter, lfilter
import matplotlib.pyplot as plt

# Generate a noisy signal
fs = 1000  # Sampling frequency
t = np.arange(0, 1, 1/fs)  # Time vector
signal = np.sin(2 * np.pi * 5 * t)  # A 5 Hz sine wave
noise = 0.5 * np.random.normal(size=len(t))  # Gaussian noise
noisy_signal = signal + noise

# Define the low-pass filter
cutoff_frequency = 5  # Cutoff frequency in Hz
nyquist_frequency = 0.5 * fs
b, a = butter(1, cutoff_frequency / nyquist_frequency, btype='low')

# Apply the filter
filtered_signal = lfilter(b, a, noisy_signal)

# Plot the original, noisy, and filtered signals
plt.figure(figsize=(10, 6))
plt.plot(t, signal, label='Original Signal', lw=2)
plt.plot(t, noisy_signal, label='Noisy Signal', alpha=0.7)
plt.plot(t, filtered_signal, label='Filtered Signal', lw=2)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.legend()
plt.title('Low-Pass Butterworth Filter Example')
plt.grid(True)
plt.show()
